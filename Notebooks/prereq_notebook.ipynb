# %% [markdown]
# Hello! My name is Ellinor Smith and I am the Content Marketing and Media Relations Manager at 1si Chamber of Commerce. I look forward to brainstorming how I can utilize data analysis to strengthen my work in media and how to bolster our efforts in organizing member information. Outside of work, I enjoy going new places, being with friends, learning new skills, traveling, and photography.

# %%
program_name='Code:You'
print (program_name)
